# %% [markdown]
# <a href="https://colab.research.google.com/github/tebe-m/alx-low_level_programming/blob/master/Session1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = {"Name":"Tebello", "Subject":"Python for Data Science", "Course":"Post. Grad in Data Science", "Duration":12}
prinprint(student)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3158/2972592558.py in <cell line: 0>()
#       1 student = {"Name":"Tebello", "Subject":"Python for Data Science", "Course":"Post. Grad in Data Science", "Duration":12}
# ----> 2 prinprint(student)
#
# NameError: name 'prinprint' is not defined
